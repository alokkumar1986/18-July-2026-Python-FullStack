# %% [markdown]
# <a href="https://colab.research.google.com/github/alokkumar1986/18-July-2026-Python-FullStack/blob/main/tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t = (1, 2, 3, 4)
print(type(t))
# Out:
# <class 'tuple'>

# %%
t = 1, 2, 3, 5
print(type(t))
# Out:
# <class 'tuple'>

# %%
t = tuple((1, 2, 3, 4))
print(type(t))
# Out:
# <class 'tuple'>

# %%
t = tuple([1, 2, 3, 4])
print(type(t))
# Out:
# <class 'tuple'>

# %%
l = [1, 2, 3, 4]
print(type(l))
# Out:
# <class 'list'>

# %%
l = list((1, 2, 3, 4))
print(type(l))
# Out:
# <class 'list'>

# %%
l = list([1, 2, 3, 4])
print(type(l))
# Out:
# <class 'list'>

# %%
l = [] #empty list
t = () #empty tuple

print(type(l))
print(type(t))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
l = [1]
t = (1,)
print(type(l))
print(type(t))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
l = [1, 2, 3, 4]
l[2] = 7
print(l)
# Out:
# [1, 2, 7, 4]

# %%
t = (1, 2, 3, 4)
t[2] = 7
print(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1033/229653697.py in <cell line: 0>()
#       1 t = (1, 2, 3, 4)
# ----> 2 t[2] = 7
#       3 print(t)
#
# TypeError: 'tuple' object does not support item assignment
