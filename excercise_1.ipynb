# %% [markdown]
# <a href="https://colab.research.google.com/github/alokkumar1986/18-July-2026-Python-FullStack/blob/main/excercise_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#write a program to read student infromation from the user and print
name = input('Enter student name : ')
age = input('Enter student age : ')
branch = input('Enter student branch : ')

print('Student Name : ',name)
print('Student Age : ',age)
print('Student Branch : ',branch)
# Out:
# Enter student name : Ardhendu
# Enter student age : 23
# Enter student branch : CSE
# Student Name :  Ardhendu
# Student Age :  23
# Student Branch :  CSE

# %%
#write a program to read three numbers from the keyboard, print them with sep='+' and their sum

num1 = int(input('Enter first number : '))
num2 = int(input('Enter second number : '))
num3 = int(input('Enter third number : '))

print(num1,num2,num3,sep='+', end="=")
print(num1+num2+num3)
# Out:
# Enter first number : 10
# Enter second number : 15
# Enter third number : 20
# 10+15+20=45
