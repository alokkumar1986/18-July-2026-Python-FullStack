# %% [markdown]
# <a href="https://colab.research.google.com/github/alokkumar1986/18-July-2026-Python-FullStack/blob/main/input_output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = input('Enter first number : ')
num2 = input('Enter second number : ')
print(num1+num2)

print(int(num1)+int(num2))
# Out:
# Enter first number : 100
# Enter second number : 10
# 10010
# 110

# %%
a = input('Enter First Value : ')
# Out:
# Enter First Value : 1008968jbkjbkj;lls';dkjka

# %%
x = float(input('Enter 1st val : '))
y = int(input('Enter 2nd val : '))
print(x+y)
# Out:
# Enter 1st val : 100
# Enter 2nd val : 10
# 110.0

# %%
print('Aptech Learning Center')
print('Alok Kumar Nayak')
# Out:
# Aptech Learning Center
# Alok Kumar Nayak

# %%
a = 100
print(a)
# Out:
# 100

# %%
print('Alok', 'Kumar')
print()
print('Nayak')
# Out:
# Alok Kumar
#
# Nayak

# %%
print('     *')
print('    * *')
print('   * * *')
print('  * * * *')
print(' * * * * *')
# Out:
#      *
#     * *
#    * * *
#   * * * *
#  * * * * *

# %%
a = 100
b = 10
c = 20.23
print(a, b, c)
# Out:
# 100 10 20.23

# %%
a = input('What is your name : ')
print('My name is : ', a)
# Out:
# What is your name : Alok
# My name is :  Alok

# %%
a = 100
b = 10
c = 5

print('A value is', a, 'B value is', b, 'C value is', c)
# Out:
# A value is 100 B value is 10 C value is 5
