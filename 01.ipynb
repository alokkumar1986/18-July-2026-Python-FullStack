# %% [markdown]
# <a href="https://colab.research.google.com/github/alokkumar1986/18-July-2026-Python-FullStack/blob/main/01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))
print("The sum is:", a + b)
# Out:
# Enter the first number:  90
# Enter the second number:  9
# The sum is: 99

# %%
# Get two numbers from the user
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))

print(f"Before swapping: num1 = {num1}, num2 = {num2}")

# Swap the numbers using a temporary variable
temp = num1
num1 = num2
num2 = temp

print(f"After swapping: num1 = {num1}, num2 = {num2}")
# Out:
# Enter the first number:  90
# Enter the second number:  9
# Before swapping: num1 = 90, num2 = 9
# After swapping: num1 = 9, num2 = 90
