# %% [markdown]
# <a href="https://colab.research.google.com/github/alokkumar1986/18-July-2026-Python-FullStack/blob/main/list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [10, 10.5, 1+9j, 'Aptech']

print(type(a))
# Out:
# <class 'list'>

# %%
a = [10, 10.5, 1+9j, 'Aptech']

print(a[0]) #10
print(a[1]) #10.5
print(a[2]) #1+9j
print(a[3]) #'Aptech'
#print(a[4]) #Error
# Out:
# 10
# 10.5
# (1+9j)
# Aptech
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1565/3132904527.py in <cell line: 0>()
#       5 print(a[2]) #1+9j
#       6 print(a[3]) #'Aptech'
# ----> 7 print(a[4]) #Error
#
# IndexError: list index out of range

# %%
a = [10, 10.5, 1+9j, 'Aptech']

print(a[-1]) #'Aptech'
print(a[-2]) #1+9j
print(a[-3]) #10.5
print(a[-4]) #10
print(a[-5]) #Error
# Out:
# Aptech
# (1+9j)
# 10.5
# 10
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1565/1614195180.py in <cell line: 0>()
#       5 print(a[-3]) #10.5
#       6 print(a[-4]) #10
# ----> 7 print(a[-5]) #Error
#
# IndexError: list index out of range

# %%
a = [10, 10.5, 1+9j, 'Aptech']

a[0] = 15

print(a)
# Out:
# [15, 10.5, (1+9j), 'Aptech']

# %%
a = [10, 10.5, 1+9j, 'Aptech']

a.append('Aptech')

print(a)
# Out:
# [10, 10.5, (1+9j), 'Aptech', 'Aptech']

# %%
a = [10, 10.5, 1+9j, 'Aptech']

a.append('Aptech')

a.append('23')

print(a)
# Out:
# [10, 10.5, (1+9j), 'Aptech', 'Aptech', '23']

# %%
a = [10, 10.5, 1+9j, 'Aptech']

a.append('Aptech')

a.append('23')

print(a)

a.pop()
print(a)

a.pop()
print(a)
# Out:
# [10, 10.5, (1+9j), 'Aptech', 'Aptech', '23']
# [10, 10.5, (1+9j), 'Aptech', 'Aptech']
# [10, 10.5, (1+9j), 'Aptech']

# %%
#write a program to construct a list of all the student names.

name = ['OM Prakas', 'Adyasa', 'Arpita', 'Sanjog']
print(name)
# Out:
# ['OM Prakas', 'Adyasa', 'Arpita', 'Sanjog']
