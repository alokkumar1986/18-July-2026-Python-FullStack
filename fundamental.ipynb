# %% [markdown]
# <a href="https://colab.research.google.com/github/alokkumar1986/18-July-2026-Python-FullStack/blob/main/fundamental.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = 10

print(id(num1))
# Out:
# 11645640

# %%
a = -12
print(type(a))
# Out:
# <class 'int'>

# %%
a = 1000000000000
print(type(a))
# Out:
# <class 'int'>

# %%
a = 3.24
print(type(a))
# Out:
# <class 'float'>

# %%
a = -3.24
print(type(a))
# Out:
# <class 'float'>

# %%
k = 10.0
print(type(k))
# Out:
# <class 'float'>

# %%
a = 10
b = 10.0

a = b

print(type(a))
# Out:
# <class 'float'>

# %%
a = 10
b = 10.0

b = a

print(type(b))
# Out:
# <class 'int'>

# %%
a = 10
b = 5
c = a/b
print(type(c))
# Out:
# <class 'float'>

# %%
a = 10.0
b = 5.0
c = a/b
print(type(c))
# Out:
# <class 'float'>

# %%
from posixpath import join
a = 10+2j
print(type(a))

b = -1-1j
print(type(b))

c = 100j
print(type(c))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %%
a = 10+10j
b = 5-5j
print(a+b)
# Out:
# (15+5j)

# %%
a = 10+10j
b = 5-5j
print(a-b)
# Out:
# (5+15j)

# %%
a = 10+10j
b = 5-5j
print(a*b)
# Out:
# (100+0j)

# %%
a = 10+10j
b = 5-5j
print(a/b)
# Out:
# 2j

# %%
x = 100+100j
print(x.real)
print(x.imag)
# Out:
# 100.0
# 100.0

# %%
#write a program to take input a complex number from user and print its imaginary part

num = complex(input('Enter a complex number : '))

print(num.imag)
# Out:
# Enter a complex number : 10+2j
# 2.0

# %%
a = 'Aptech'

print(type(a))
# Out:
# <class 'str'>

# %%
a = "Aptech"

print(type(a))
# Out:
# <class 'str'>

# %%
a = 'Aptech"

print(type(a))
# Out:
#   File "/tmp/ipykernel_1148/4139952689.py", line 1
#     a = 'Aptech"
#         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
a = '123&687685RAM'
print(type(a))
# Out:
# <class 'str'>

# %%
a = '123&687685RAM'

print(a[10])
# Out:
# R

# %%
a = '123&687685RAM'

print(a[-5])
# Out:
# 8

# %%
a = '123&687685RAM'
print(a[0:3])
print(a[2:5])
# Out:
# 123
# 3&6

# %%
a = '123&687685RAM'

print(a[0:3]) #123

print(a[2:5]) #3&6

print(a[:5]) #123&6

print(a[2:]) #3&687685RAM

print(a[:]) #123&687685RAM

print(a[1:7:2]) #2&8

print(a[:7:4])  #16

print(a[::5])   #18R

print(a[-5:-1]) #5RAM
# Out:
# 123
# 3&6
# 123&6
# 3&687685RAM
# 123&687685RAM
# 2&8
# 16
# 18R
# 85RA

# %%
a = '123&687685RAM'
print(a[:-2])  #123&687685R

print(a[-8:])

print(a[::-1])
# Out:
# 123&687685R
# 87685RAM
# MAR586786&321

# %%
#write a program to take your name as input and print its reverse.

name = input('Enter your name : ')

print(name[::-1])
# Out:
# Enter your name : Aptech
# hcetpA

# %%
a = 'abcdefghijklmnopqrstuvwxyz'
print(a[0:1000])
print(a[-1000:])
# Out:
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz

# %%
a = """Aptech
Learning"""
print(a)
# Out:
# Aptech
# Learning

# %%
a = """Aptech
Learning"""

print(len(a))
# Out:
# 15

# %%
a = """Aptech
Learning"""
print(a.upper())
# Out:
# APTECH
# LEARNING

# %%
a = """Aptech
Learning"""
print(a.lower())
# Out:
# aptech
# learning

# %%
a = """Aptech
Learning"""
print(a.capitalize())
# Out:
# Aptech
# learning

# %%
name = 'Harish Shahshra'
print(name[0].upper()+name[1:(len(name)-1)].lower()+name[len(name)-1].upper())
# Out:
# Harish shahshrA

# %%
name = 'Harish Shahshra'

print(name.title())

print(name.swapcase())
# Out:
# Harish Shahshra
# hARISH sHAHSHRA

# %%
name = '   Harish Shahshra   '
print(name)
print(name.strip())
# Out:
#    Harish Shahshra
# Harish Shahshra

# %%
name = '   Harish Shahshra   '
print(name)

print(name.lstrip())
print(name.rstrip())
# Out:
#    Harish Shahshra
# Harish Shahshra
#    Harish Shahshra

# %%
name = 'Harish Shahshra'
a = name.replace('H', 's', -1)

a = a.replace('h', 's', -1)
print(a)
# Out:
# sariss Ssasssra

# %%
a = "Aptech Learning Center"

# output : relace all e with s

b = a.replace('e', 's', -1)

print(b)
# Out:
# Aptsch Lsarning Csntsr

# %%
a = "Bhubaneswar Aptech Learning Center"
print(a.find('Aptech'))
# Out:
# 12

# %%
a = "Aptech Learning Center"
print(a.index('Aptech'))
# Out:
# 0

# %%
a = "Bhubaneswar Aptech Learning Center"
print(a.find('NM'))
# Out:
# -1

# %%
a = "Bhubaneswar Aptech Learning Center"
print(a.index('NM'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1140/4193633672.py in <cell line: 0>()
#       1 a = "Bhubaneswar Aptech Learning Center"
# ----> 2 print(a.index('NM'))
#
# ValueError: substring not found

# %%
a = "Bhubaneswar Aptech Learning Center"
print(a.rfind(a[12:17]))
# Out:
# 12

# %%
a = "Bhubaneswar Aptech Learning Center"
print(a.rindex('Aptech'))
# Out:
# 12

# %%
s = 'aptech Learing center, bhubaneswar'
a = s.count('a')
print(a)
# Out:
# 4

# %%
s = 'Aptech Learing center, bhubaneswar'
print(s.startswith('Aptech'))

if(s.startswith('Aptech')):
  print('Yes')
else:
  print('No')
# Out:
# False
# Yes

# %%
s = 'Aptech Learing center, bhubaneswar'
print(s.endswith('bhu'))
# Out:
# False

# %%
s = 'Aptech Learing center'
s1 = ', bhubaneswar'.join([s, ""])

print(s1)
# Out:
# Aptech Learing center, bhubaneswar

# %%
s = 'Aptech Learing center bhubaneswar'
s1 = s.split('/')
print(s1)
# Out:
# ['Aptech Learing center bhubaneswar']

# %%
#write a program to take your full name as input and count number of words
#and number of characters in it.

name = input('Enter your full name : ')

print('Number of words :', name.count(' ')+1)

print('Number of characters : ', len(name))
# Out:
# Enter your full name : Sachin Ramesh Tendulkar
# Number of words : 3
# Number of characters :  23

# %%
s = '''This is
multiline
string'''

# %%
rice = 1
potato = 2

#rice 1kg and potato 2kg

s = f"rice {rice}kg and potato {potato}kg"
print(s)
# Out:
# rice 1kg and potato 2kg

# %%
students = 100
boys = 70

s = f"In the school, there are {students} students and out them {boys} are boys and {students-boys} are girls"

print(s)
# Out:
# In the school, there are 100 students and out them 70 are boys and 30 are girls
