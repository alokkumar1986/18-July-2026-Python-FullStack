# %% [markdown]
# <a href="https://colab.research.google.com/github/alokkumar1986/18-July-2026-Python-FullStack/blob/main/operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 5
b = 3

print(a & b)
# Out:
# 1

# %%
a = 3
b = 5
print(a & b)
# Out:
# 1

# %%
a = 10
b = 8
print(10 & 8)
# Out:
# 8

# %%
a = 15

print(bin(15))
b = 12
print(bin(12))

print(a & b)

print(0b1100)
# Out:
# 0b1111
# 0b1100
# 12
# 12

# %%
a = 12
print(oct(12))
# Out:
# 0o14

# %%
a = 12
print(hex(a))
# Out:
# 0xc

# %%
a = 0xc
print(a)
# Out:
# 12

# %%
#0xc convert it to binary

a = 0xc
print(bin(0xc))
# Out:
# 0b1100

# %%
#0xc convert it to octal
a = 0xc
print(oct(a))
# Out:
# 0o14

# %%
a = 5  #convert it to bin = 101
b = 3  #convert it to bin = 011
print(a | b) # apply logical or 111 = 7
# Out:
# 7

# %%
a = 5 #convert it to bin 101
b = 3 #convert it to bin 011
print(a ^ b)  #when only one is 1 between two operands, return 1 (0,1 / 1,0)
              # in other cases return 0 (1,1/0,0)
# Out:
# 6

# %%
a = 5
print(~a)  # add 1 to the operand and change the sign.
# Out:
# -6

# %%
a = -10
print(~a)
# Out:
# 9

# %%
a = 5  #convert it to bin 101
b = 3  #
print(a<<b) # then left shift the digits by number of 2nd operand
# Out:
# 40

# %%
a = 5
b = 3
print(a >> b)
# Out:
# 0

# %%
a = 10 #1010
b = 8
print(a << b)
print(a >> b)
# Out:
# 2560
# 0

# %%
a := 5  #walrus operator which was till python 3.8 version
print(a)
# Out:
#   File "/tmp/ipykernel_2027/2492417839.py", line 1
#     a := 5
#       ^
# SyntaxError: invalid syntax
