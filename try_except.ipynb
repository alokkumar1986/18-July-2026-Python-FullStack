# %% [markdown]
# <a href="https://colab.research.google.com/github/alokkumar1986/18-July-2026-Python-FullStack/blob/main/try_except.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3223/1353120783.py in <cell line: 0>()
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %%
#y = 5
try :
 print(y)
except :
  print("An exeption occured due to y is not defined")
else:
  print('There is no exception')
finally:
  print('Program Ends')
# Out:
# An exeption occured due to y is not defined
# Program Ends

# %%
x = 5
try :
 print(x)
except :
  print("An exeption occured due to x is not defined")
else:
  print('There is no exception')
finally:
  print('Program Ends')
# Out:
# 5
# There is no exception
# Program Ends

# %%
try :
   print(p)
except:
   print('Exception: p is not defined')
# Out:
# Exception: p is not defined

# %%
p= 10
try :
   print(p)
except:
   print('Exception: p is not defined')
# Out:
# 10

# %%
p= 10
try :
   print(p)
finally:
   print('There is no exception')
# Out:
# 10
# There is no exception

# %%
try :
   print(q)
finally:
   print('There is no exception')
# Out:
# There is no exception
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3223/1417946775.py in <cell line: 0>()
#       1 try :
# ----> 2    print(q)
#       3 finally:
#       4    print('There is no exception')
#
# NameError: name 'q' is not defined

# %%
m = 20
try :
 print(m)
except:
  pass
else:
  print('there is no exception')
# Out:
# 20
# there is no exception

# %%
m = 20
try :
 print(m)
else:
  print('there is no exception')
except:
  pass
# Out:
#   File "/tmp/ipykernel_3223/1618401314.py", line 4
#     else:
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %%
try :
 print(k)
# except NameError:
#   print('Exception due to NameError')
# except Error:
#   print('Exception due to Error')
except :
  print('Exception without ant Error specification')
# Out:
# Exception without ant Error specification

# %%
l = [1, 2, 3, 4]
try :
  print(l[5])
except NameError:
  print('Exception due to NameError')
except IndexError:
  print('Exception due to out of Index Range')
except :
  print('Exception without any Error specification')
# Out:
# Exception due to out of Index Range

# %%
x = 10
print(x/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_3223/105249834.py in <cell line: 0>()
#       1 x = 10
# ----> 2 print(x/0)
#
# ZeroDivisionError: division by zero

# %%
x = 10
try :
  print(x/0)
except NameError:
  print('Exception due to NameError')
except IndexError:
  print('Exception due to out of Index Range')
except :
  print('Exception without any Error specification')
# Out:
# Exception without any Error specification

# %%
x = 10
try :
  print(x/0)
except NameError:
  print('Exception due to NameError')
except IndexError:
  print('Exception due to out of Index Range')
except ZeroDivisionError:
  print('Exception due to division with 0')
except :
  print('Exception without any Error specification')
# Out:
# Exception due to division with 0

# %%
x = 10
try :
  print(x)
except NameError:
  print('Exception due to NameError')
else:
  print('There is no exception')
else:
  print('x is defined, so no exeption')
# Out:
#   File "/tmp/ipykernel_3223/1083523979.py", line 8
#     else:
#     ^
# SyntaxError: invalid syntax
