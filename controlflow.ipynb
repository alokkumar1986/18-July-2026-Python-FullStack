# %% [markdown]
# <a href="https://colab.research.google.com/github/alokkumar1986/18-July-2026-Python-FullStack/blob/main/controlflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#write a program to check the number is palindrome

num = input('Enter a number : ')
if num[:] == num[::-1]:
   print('Palindrome')
# Out:
# Enter a number : 11
# Palindrome

# %%
#write a program to check the number is palindrome

num = input('Enter a number : ')
if num[:] == num[::-1]:
   print('Palindrome')
else:
   print('Not palindrome')
# Out:
# Enter a number : 101
# Palindrome

# %%
#write a program to input one digit number and print it in words

num = int(input('Enter a one digit number :'))

if num==0:
   print('Zero')
elif num==1:
   print('One')
elif num==2:
   print('Two')
elif num==3:
   print('Three')
elif num==4:
   print('Four')
elif num==5:
   print('Five')
elif num==6:
   print('Six')
elif num==7:
   print('Seven')
elif num==8:
   print('Eight')
elif num==9:
   print('Nine')
else:
  print('Wrong Number')
# Out:
# Enter a one digit number :100
# Wrong Number

# %%
for I in 'Learning':
   print('A')
# Out:
# A
# A
# A
# A
# A
# A
# A
# A

# %%
for I in 'Learning':
   print(I)
# Out:
# L
# e
# a
# r
# n
# i
# n
# g

# %%
while(True):
  print('Aptech')
# Out:
# Streaming output truncated to the last 5000 lines.
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# ...

# %%
i = 1
while(i<=10):
  print('Aptech')
  i+=1
# Out:
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech
# Aptech

# %%
for i in range(10):
  print('Hello')
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
#Find the sum of numbers present in list

l = [1, 4, 2, 5, 3, 4, 5]
sum = 0
for i in l:
   sum+=i
print('Sum : ', sum)
# Out:
# Sum :  24

# %%
for i in range(5):
   if i==3:
     continue
   print(i)
# Out:
# 0
# 1
# 2
# 4

# %%
for i in range(5):
   if i==3:
     break
   print(i)
# Out:
# 0
# 1
# 2

# %%
i = 0
while i<=10:
   i+=1
   if i==5:
      continue
   print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10
# 11

# %%
i = 0
while i<=10:
   i+=1
   if i==5:
      break
   print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(5):
  pass

# %%
i = 1
while i<=10:
  pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_575/1979798494.py in <cell line: 0>()
#       1 i = 1
# ----> 2 while i<=10:
#       3   pass
#
# KeyboardInterrupt:
