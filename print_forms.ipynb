# %% [markdown]
# <a href="https://colab.research.google.com/github/alokkumar1986/18-July-2026-Python-FullStack/blob/main/print_forms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 100

print(type(a))
# Out:
# <class 'int'>

# %%
num1 = input('Enter first number')

print(type(num1))

num1 = int(num1)

print(type(num1))
# Out:
# Enter first number100
# <class 'str'>
# <class 'int'>

# %%
num1 = int(input('Enter first number'))

print(type(num1))
# Out:
# Enter first number100
# <class 'int'>

# %%
num1 = int(input('Enter first number'))
num2 = int(input('Enter second number'))

print(num1 + num2)
# Out:
# Enter first number100
# Enter second number2000
# 2100

# %%
print('Aptech')
print('Learning')
# Out:
# Aptech
# Learning

# %%
print('Hi')
print()
print('Hello')
print('Aptech Learning')
print()
print('Bhubaneswar')
# Out:
# Hi
#
# Hello
# Aptech Learning
#
# Bhubaneswar

# %%
print('Odisha (Oriya: oṛiśā, pronounced [oɽisa] ⓘ), spelled Orissa until 2011,[19] is a state located in eastern India. It is the eighth-largest state by area, and the eleventh-largest by population, with over 41 million inhabitants. The state also has the third-largest population of Scheduled Tribes in India.[20] It neighbours the states of Jharkhand and West Bengal to the north, Chhattisgarh to the west, and Andhra Pradesh to the south. Odisha has a coastline of 485 kilometres (301 mi) along the Bay of Bengal in the Indian Ocean.[21] The region is also known as Utkaḷa and is mentioned by this name in Indias national anthem, Jana Gana Mana.')
# Out:
# Odisha (Oriya: oṛiśā, pronounced [oɽisa] ⓘ), spelled Orissa until 2011,[19] is a state located in eastern India. It is the eighth-largest state by area, and the eleventh-largest by population, with over 41 million inhabitants. The state also has the third-largest population of Scheduled Tribes in India.[20] It neighbours the states of Jharkhand and West Bengal to the north, Chhattisgarh to the west, and Andhra Pradesh to the south. Odisha has a coastline of 485 kilometres (301 mi) along the Bay of Bengal in the Indian Ocean.[21] The region is also known as Utkaḷa and is mentioned by this name in Indias national anthem, Jana Gana Mana.

# %%
print('Aptech Learning Center, \nBhubaneswar')
# Out:
# Aptech Learning Center,
# Bhubaneswar

# %%
print('Aptech\tLearning\tCenter,\tBhubaneswar')
# Out:
# Aptech	Learning	Center,	Bhubaneswar

# %%
print('Ram\'s book')
print("Ram's book")
# Out:
# Ram's book
# Ram's book
# Ram s book

# %%
print('Hello\rWorld')
# Out:
# World

# %%
print('Hi, Welcome to Aptech\rLearning center')
# Out:
# Learning center

# %%
print('Apte\rch')
# Out:
# ch

# %%
print('At\\po : Bhubaneswar')
# Out:
# At\po : Bhubaneswar

# %%
print("\"Sachin\" is known as God of Cricket")
# Out:
# "Sachin" is known as God of Cricket

# %%
a = 100
b = 'Aptech'
print(a)
print(b)
# Out:
# 100
# Aptech

# %%
print('Aptech', 'Learning', 'center')
# Out:
# Aptech Learning center

# %%
a = 100
print('Value of a : ', a)
# Out:
# Value of a :  100

# %%
a = 100
b = 'Aptech'
c = 3.14

print('Value of a :', a, 'Value of b : ', b, 'Value of c : ', c)

print('a=', a, end=', ')
print('b=', b, end=', ')
print('c=', c)


print('a= {}, b= {}, c= {}'.format(a,b,c))
# Out:
# Value of a : 100 Value of b :  Aptech Value of c :  3.14
# a= 100, b= Aptech, c= 3.14
# a= 100, b= Aptech, c= 3.14
