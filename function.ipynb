# %% [markdown]
# <a href="https://colab.research.google.com/github/alokkumar1986/18-July-2026-Python-FullStack/blob/main/function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello Alice')
print('Hello Tom')
print('Hello Robin')
# Out:
# Hello Alice
# Hello Tom
# Hello Robin

# %%
def sayHello(name):
  print('Hello', name)

sayHello('Alice')
sayHello('Tom')
# Out:
# Hello Alice
# Hello Tom

# %%
def sayHello(name, name1):
  print('Hello', name,'&', name1)

sayHello('Alice', 'Tom')
# Out:
# Hello Alice & Tom

# %%
#Write a program to find the sum of two number using fuction

def findSum(a, b):
   print('Sum : ', a+b)

findSum(5, 6)
findSum(100, 101)
# Out:
# Sum :  11
# Sum :  201

# %%
def findSum(a, b):
   return a+b


sum = findSum(5,6)
print('Sum :', sum)

# %%
def findSum(a, b):
   print('Sum : ', a+b)

sum = findSum(5, 6)
print('Sum : ', sum)
# Out:
# Sum :  11
# Sum :  None

# %%
def findSumDiff(a, b):
   return a+b, a-b


val = findSumDiff(5,6)
print(val)
print('Sum :', val[0])
print('Difference :', val[1])
# Out:
# (11, -1)
# Sum : 11
# Difference : -1

# %%
#write a program of calculator using function.

def findSum(a,b):
  return a+b

def findDiff(a,b):
  return a-b

def findMul(a,b):
  return a*b

def findDiv(a, b):
  return a/b

def findFloorDiv(a,b):
   return a//b

def findMod(a,b):
   return a%b

def findPower(a,b):
  return a**b

print('Sum : ', findSum(5,6))
print('Difference : ', findDiff(5,6))
print('Multiplication : ', findMul(5,6))
print('Division :', findDiv(5,6))
print('Floor Division :', findFloorDiv(5,6))
print('Modulus :', findMod(5,6))
print('Power :', findPower(5,6))
# Out:
# Sum :  11
# Difference :  -1
# Multiplication :  30
# Division : 0.8333333333333334
# Floor Division : 0
# Modulus : 5
# Power : 15625

# %%
def sayHello(name='Alice'):
   print('Hello', name)

sayHello()
# Out:
# Hello Alice

# %%
def sayHello(name='Alice'):
   print('Hello', name)

sayHello('Tom')
# Out:
# Hello Tom

# %%
def sayHello(name='Alice', age):
   print('Hello', name)
   print('Your age :', age)

sayHello(20)
# Out:
#   File "/tmp/ipykernel_1730/239443910.py", line 1
#     def sayHello(name='Alice', age):
#                                ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
def sayHello(age, name='Alice'):
   print('Hello', name)
   print('Your age :', age)

sayHello(20)
# Out:
# Hello Alice
# Your age : 20

# %%
def sayHello(course='Python', age, name='Alice'):
   print('Hello', name)
   print('Your age :', age)
   print('Course : ', course)
sayHello(20)
# Out:
#   File "/tmp/ipykernel_1730/2499796115.py", line 1
#     def sayHello(course='Python', age, name='Alice'):
#                                   ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
def sayHello(age, course='Python', name='Alice'):
   print('Hello', name)
   print('Your age :', age)
   print('Course : ', course)
sayHello(20)
# Out:
# Hello Alice
# Your age : 20
# Course :  Python

# %%
def sayHello(age, course='Python', name='Alice'):
   print('Hello', name)
   print('Your age :', age)
   print('Course : ', course)
sayHello(20, 'Tom')
# Out:
# Hello Alice
# Your age : 20
# Course :  Tom

# %%
def sayHello(age, course='Python', name='Alice'):
   print('Hello', name)
   print('Your age :', age)
   print('Course : ', course)
sayHello(20, 'MySQL', 'Bob')
# Out:
# Hello Bob
# Your age : 20
# Course :  MySQL

# %%
def sayHello(course, age, name):
   print('Hello', name)
   print('Your age :', age)
   print('Course : ', course)

sayHello('Python', 20, 'Alice')
# Out:
# Hello Alice
# Your age : 20
# Course :  Python

# %%
def sayHello(course, age, name):
   print('Hello', name)
   print('Your age :', age)
   print('Course : ', course)

sayHello(20, 'Python', 'Alice')
# Out:
# Hello Alice
# Your age : Python
# Course :  20

# %%
def sayHello(age, course, name):
   print('Hello', name)
   print('Your age :', age)
   print('Course : ', course)

sayHello(20, 'Python', 'Alice')
# Out:
# Hello Alice
# Your age : 20
# Course :  Python

# %%
def sayHello(course, age, name):
   print('Hello', name)
   print('Your age :', age)
   print('Course : ', course)

sayHello(course='Python', age=20, name='Alice')
# Out:
# Hello Alice
# Your age : 20
# Course :  Python

# %%
def sayHello(course, age, name):
   print('Hello', name)
   print('Your age :', age)
   print('Course : ', course)

sayHello(age=20, course='Python', name='Alice')
# Out:
# Hello Alice
# Your age : 20
# Course :  Python

# %%
def sayHello(age, course,  name):
   print('Hello', name)
   print('Your age :', age)
   print('Course : ', course)

sayHello(20, course='Python',  name='Alice')
# Out:
# Hello Alice
# Your age : 20
# Course :  Python

# %%
def sayHello(age, course,  name):
   print('Hello', name)
   print('Your age :', age)
   print('Course : ', course)

sayHello(course='Python',  20,  name='Alice')
# Out:
#   File "/tmp/ipykernel_1730/1664818069.py", line 6
#     sayHello(course='Python',  20,  name='Alice')
#                                                 ^
# SyntaxError: positional argument follows keyword argument

# %%
def sayHello( course, age,  name):
   print('Hello', name)
   print('Your age :', age)
   print('Course : ', course)

sayHello( 20, course='Python',   name='Alice')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1730/2607294450.py in <cell line: 0>()
#       4    print('Course : ', course)
#       5
# ----> 6 sayHello( 20, course='Python',   name='Alice')
#
# TypeError: sayHello() got multiple values for argument 'course'

# %%
def sayHello(*arg):
   print(type(arg))
   print('Hello', arg[2])
   print('Your age :', arg[0])
   print('Course : ', arg[1])

sayHello(20,'Python', 'Alice')
# Out:
# <class 'tuple'>
# Hello Alice
# Your age : 20
# Course :  Python
